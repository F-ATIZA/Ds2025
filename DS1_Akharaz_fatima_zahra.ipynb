# %% [markdown]
# <a href="https://colab.research.google.com/github/F-ATIZA/Ds2025/blob/main/DS1_Akharaz_fatima_zahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn jupyter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 103.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Charger un dataset en ligne (exemple : ventes d'une entreprise)
url = "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
df = pd.read_csv(url)

# %%
display(df)
# Out:
#       Country Name Country Code  Year         Value
# 0      Afghanistan          AFG  2000  3.521418e+09
# 1      Afghanistan          AFG  2001  2.813572e+09
# 2      Afghanistan          AFG  2002  3.825701e+09
# 3      Afghanistan          AFG  2003  4.520947e+09
# 4      Afghanistan          AFG  2004  5.224897e+09
# ...            ...          ...   ...           ...
# 13974     Zimbabwe          ZWE  2019  2.183223e+10
# 13975     Zimbabwe          ZWE  2020  2.150970e+10
# 13976     Zimbabwe          ZWE  2021  2.837124e+10
# 13977     Zimbabwe          ZWE  2022  2.736663e+10
# 13978     Zimbabwe          ZWE  2023  2.653827e+10
#
# [13979 rows x 4 columns]

# %% [markdown]
# This step displays the first few rows of the DataFrame `df` using the `.head()` method. This is useful for getting a quick preview of the data and its structure.

# %%
# Afficher les premières lignes
print(df.head())
# Out:
#   Country Name Country Code  Year         Value
# 0  Afghanistan          AFG  2000  3.521418e+09
# 1  Afghanistan          AFG  2001  2.813572e+09
# 2  Afghanistan          AFG  2002  3.825701e+09
# 3  Afghanistan          AFG  2003  4.520947e+09
# 4  Afghanistan          AFG  2004  5.224897e+09

# %%
# Informations sur le dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13979 entries, 0 to 13978
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  13979 non-null  object
#  1   Country Code  13979 non-null  object
#  2   Year          13979 non-null  int64
#  3   Value         13979 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 437.0+ KB
# None

# %% [markdown]
# This step displays information about the DataFrame `df` using the `.info()` method. This is useful for seeing the column names, non-null counts, and data types.

# %%
# Statistiques descriptives
print(df.describe())
# Out:
#                Year         Value
# count  13979.000000  1.397900e+04
# mean    1994.672866  1.207380e+12
# std       17.731413  5.537517e+12
# min     1960.000000  1.150263e+04
# 25%     1980.000000  2.233880e+09
# 50%     1996.000000  1.672591e+10
# 75%     2010.000000  2.058542e+11
# max     2023.000000  1.054350e+14

# %% [markdown]
# This step displays descriptive statistics of the DataFrame `df` using the `.describe()` method. This is useful for getting a summary of the central tendency, dispersion, and shape of the distribution of numerical columns.

# %%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13979 entries, 0 to 13978
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  13979 non-null  object
#  1   Country Code  13979 non-null  object
#  2   Year          13979 non-null  int64
#  3   Value         13979 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 437.0+ KB
# None
#                Year         Value
# count  13979.000000  1.397900e+04
# mean    1994.672866  1.207380e+12
# std       17.731413  5.537517e+12
# min     1960.000000  1.150263e+04
# 25%     1980.000000  2.233880e+09
# 50%     1996.000000  1.672591e+10
# 75%     2010.000000  2.058542e+11
# max     2023.000000  1.054350e+14

# %%
#calculer Moyenne
print(f"Moyenne: {colonne.mean():.2f}")
#calculer Médiane
print(f"Médiane: {colonne.median():.2f}")
#calculer Mode
print(f"Mode: {colonne.mode()[0]:.2f}")
#calculer Ecart-type
print(f"Écart-type: {colonne.std():.2f}")
#calculer Variance
print(f"Variance: {colonne.var():.2f}")
#calculer Min
print(f"Min: {colonne.min():.2f}")
#calculer Max
print(f"Max: {colonne.max():.2f}")
# Out:
# Moyenne: 1207379525661.76
# Médiane: 16725908148.55
# Mode: 340000000.00
# Écart-type: 5537517274228.25
# Variance: 30664097562376314470531072.00
# Min: 11502.63
# Max: 105435039507024.09

# %%
# Configuration du style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

# Créer une figure avec plusieurs sous-graphiques
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Histogramme
axes[0, 0].hist(colonne, bins=30, edgecolor='black', alpha=0.7)
axes[0, 0].set_title('Distribution des valeurs', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Valeur')
axes[0, 0].set_ylabel('Fréquence')

# Ajouter la moyenne et la médiane
axes[0, 0].axvline(colonne.mean(), color='red', linestyle='--',
                   label=f'Moyenne: {colonne.mean():.2f}')
axes[0, 0].axvline(colonne.median(), color='green', linestyle='--',
                   label=f'Médiane: {colonne.median():.2f}')
axes[0, 0].legend()

# 2. Boxplot
axes[0, 1].boxplot(colonne.dropna(), vert=True)
axes[0, 1].set_title('Boxplot - Détection des outliers', fontsize=14, fontweight='bold')
axes[0, 1].set_ylabel('Valeur')

# 3. Densité
colonne.plot(kind='density', ax=axes[1, 0])
axes[1, 0].set_title('Courbe de densité', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Valeur')

# 4. QQ-plot (pour tester la normalité)
from scipy import stats
stats.probplot(colonne.dropna(), dist="norm", plot=axes[1, 1])
axes[1, 1].set_title('Q-Q Plot (Test de normalité)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 1. Histogram
plt.figure(figsize=(10, 6))
plt.hist(colonne, bins=30, edgecolor='black', alpha=0.7)
plt.title('Distribution des valeurs', fontsize=14, fontweight='bold')
plt.xlabel('Valeur')
plt.ylabel('Fréquence')
plt.axvline(colonne.mean(), color='red', linestyle='--', label=f'Moyenne: {colonne.mean():.2f}')
plt.axvline(colonne.median(), color='green', linestyle='--', label=f'Médiane: {colonne.median():.2f}')
plt.legend()
plt.show()

# %%
# 2. Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(colonne.dropna(), vert=True)
plt.title('Boxplot - Détection des outliers', fontsize=14, fontweight='bold')
plt.ylabel('Valeur')
plt.show()

# %%
# 3. Density plot
plt.figure(figsize=(10, 6))
colonne.plot(kind='density')
plt.title('Courbe de densité', fontsize=14, fontweight='bold')
plt.xlabel('Valeur')
plt.show()

# %%
# 4. QQ-plot
from scipy import stats
plt.figure(figsize=(10, 6))
stats.probplot(colonne.dropna(), dist="norm", plot=plt)
plt.title('Q-Q Plot (Test de normalité)', fontsize=14, fontweight='bold')
plt.show()

# %%
# Statistiques pour une colonne spécifique
colonne = df['Value']  # Adapter selon vos données

# %%
# Quartiles
print(f"Q1 (25%): {colonne.quantile(0.25):.2f}")
print(f"Q2 (50% - Médiane): {colonne.quantile(0.50):.2f}")
print(f"Q3 (75%): {colonne.quantile(0.75):.2f}")
print(f"IQR: {colonne.quantile(0.75) - colonne.quantile(0.25):.2f}")
# Out:
# Q1 (25%): 2233880173.42
# Q2 (50% - Médiane): 16725908148.55
# Q3 (75%): 205854212632.48
# IQR: 203620332459.06
